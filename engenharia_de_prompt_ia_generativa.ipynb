# %% [markdown]
# Neste curso, vou aprender os fundamentos dos modelos de linguagem e da Engenharia de Prompt, explorando técnicas para criar prompts eficazes em IA generativa. Também irei estudar práticas utilizadas por empresas como OpenAI, Google e Anthropic, além de conhecer integrações com APIs e aplicações práticas usando código.
